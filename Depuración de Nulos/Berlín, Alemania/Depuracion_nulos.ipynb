# %%
# Importar librerías
import pandas as pd
import numpy as np

# %%
# Cargar el dataset
df = pd.read_csv('base_berlin_filtrada.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14187 entries, 0 to 14186
# Data columns (total 50 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            14187 non-null  int64
#  1   listing_url                   14187 non-null  object
#  2   last_scraped                  14187 non-null  object
#  3   source                        14187 non-null  object
#  4   name                          14187 non-null  object
#  5   host_id                       14187 non-null  int64
#  6   host_url                      14187 non-null  object
#  7   host_name                     14174 non-null  object
#  8   host_since                    14174 non-null  object
#  9   host_location                 11217 non-null  object
#  10  host_response_time            9213 non-null   object
#  11  host_response_rate            9213 non-null   object
#  12  host_acceptance_rate          9829 non-null   object
#  13  host_is_superhost             13976 non-null  object
#  14  host_neighbourhood            5907 non-null   object
#  15  host_listings_count           14174 non-null  float64
#  16  host_total_listings_count     14174 non-null  float64
#  17  host_verifications            14174 non-null  object
#  18  host_has_profile_pic          14174 non-null  object
#  19  host_identity_verified        14174 non-null  object
#  20  neighbourhood                 6540 non-null   object
#  21  neighbourhood_cleansed        14187 non-null  object
#  22  neighbourhood_group_cleansed  14187 non-null  object
#  23  latitude                      14187 non-null  float64
#  24  longitude                     14187 non-null  float64
#  25  property_type                 14187 non-null  object
#  26  room_type                     14187 non-null  object
#  27  accommodates                  14187 non-null  int64
#  28  bathrooms                     9232 non-null   float64
#  29  bathrooms_text                14180 non-null  object
#  30  bedrooms                      12164 non-null  float64
#  31  beds                          9184 non-null   float64
#  32  amenities                     14187 non-null  object
#  33  price                         9183 non-null   object
#  34  minimum_nights                14187 non-null  int64
#  35  maximum_nights                14187 non-null  int64
#  36  minimum_nights_avg_ntm        14187 non-null  float64
#  37  maximum_nights_avg_ntm        14187 non-null  float64
#  38  availability_30               14187 non-null  int64
#  39  availability_60               14187 non-null  int64
#  40  availability_90               14187 non-null  int64
#  41  availability_365              14187 non-null  int64
#  42  number_of_reviews             14187 non-null  int64
#  43  estimated_occupancy_l365d     14187 non-null  int64
#  44  estimated_revenue_l365d       9183 non-null   float64
#  45  review_scores_rating          10838 non-null  float64
#  46  review_scores_cleanliness     10838 non-null  float64
#  47  review_scores_location        10835 non-null  float64
#  48  review_scores_value           10833 non-null  float64
#  49  reviews_per_month             10838 non-null  float64
# dtypes: float64(15), int64(11), object(24)
# memory usage: 5.4+ MB
# None

# %%
# Porcentaje Na's
# Porcentaje de NaN por columna
na_percent = df.isna().mean() * 100

# Ordenar de mayor a menor
na_percent = na_percent.sort_values(ascending=False)

print(na_percent)
# Out:
# host_neighbourhood              58.363290
# neighbourhood                   53.901459
# price                           35.271728
# estimated_revenue_l365d         35.271728
# beds                            35.264679
# host_response_rate              35.060266
# host_response_time              35.060266
# bathrooms                       34.926341
# host_acceptance_rate            30.718263
# review_scores_value             23.641362
# review_scores_location          23.627264
# reviews_per_month               23.606118
# review_scores_cleanliness       23.606118
# review_scores_rating            23.606118
# host_location                   20.934658
# bedrooms                        14.259533
# host_is_superhost                1.487277
# host_identity_verified           0.091633
# host_name                        0.091633
# host_verifications               0.091633
# host_has_profile_pic             0.091633
# host_total_listings_count        0.091633
# host_listings_count              0.091633
# host_since                       0.091633
# bathrooms_text                   0.049341
# estimated_occupancy_l365d        0.000000
# number_of_reviews                0.000000
# maximum_nights                   0.000000
# availability_90                  0.000000
# availability_60                  0.000000
# availability_30                  0.000000
# maximum_nights_avg_ntm           0.000000
# minimum_nights_avg_ntm           0.000000
# availability_365                 0.000000
# id                               0.000000
# minimum_nights                   0.000000
# amenities                        0.000000
# accommodates                     0.000000
# room_type                        0.000000
# listing_url                      0.000000
# longitude                        0.000000
# latitude                         0.000000
# neighbourhood_group_cleansed     0.000000
# neighbourhood_cleansed           0.000000
# host_url                         0.000000
# host_id                          0.000000
# name                             0.000000
# source                           0.000000
# last_scraped                     0.000000
# property_type                    0.000000
# dtype: float64

# %%
# Observar df
df
# Out:
#                         id                                       listing_url  \
# 0                     3176                 https://www.airbnb.com/rooms/3176
# 1                     9991                 https://www.airbnb.com/rooms/9991
# 2                    14325                https://www.airbnb.com/rooms/14325
# 3                    16644                https://www.airbnb.com/rooms/16644
# 4                    17904                https://www.airbnb.com/rooms/17904
# ...                    ...                                               ...
# 14182  1446408006383528333  https://www.airbnb.com/rooms/1446408006383528333
# 14183  1446861918532076953  https://www.airbnb.com/rooms/1446861918532076953
# 14184  1446862242596527946  https://www.airbnb.com/rooms/1446862242596527946
# 14185  1446993798027111825  https://www.airbnb.com/rooms/1446993798027111825
# 14186  1447175366954841201  https://www.airbnb.com/rooms/1447175366954841201
#
#       last_scraped           source  \
# 0       2025-06-21      city scrape
# 1       2025-06-21      city scrape
# 2       2025-06-21      city scrape
# 3       2025-06-21  previous scrape
# 4       2025-06-21      city scrape
# ...            ...              ...
# 14182   2025-06-20      city scrape
# 14183   2025-06-20      city scrape
# 14184   2025-06-20      city scrape
# 14185   2025-06-20      city scrape
# 14186   2025-06-21      city scrape
#
#                                                 name    host_id  \
# 0                    Fabulous Flat in great Location       3718
# 1                Geourgeous flat - outstanding views      33852
# 2                Studio Apartment in Prenzlauer Berg      55531
# 3                 In the Heart of Berlin - Kreuzberg      64696
# 4      Beautiful Kreuzberg studio - 3 months minimum      68997
# ...                                              ...        ...
# 14182                                      cozy room  420514457
# 14183       Beautiful 1-Bedroom Apartment in Wedding  595670462
# 14184                     Stunning Studio in Wedding  595670462
# 14185                  Gemütliches Boot mit Seeblick  569536089
# 14186                Apartment in the Heart of Mitte    1099703
#
#                                           host_url       host_name  \
# 0           https://www.airbnb.com/users/show/3718          Britta
# 1          https://www.airbnb.com/users/show/33852         Philipp
# 2          https://www.airbnb.com/users/show/55531  Chris + Oliver
# 3          https://www.airbnb.com/users/show/64696            Rene
# 4          https://www.airbnb.com/users/show/68997        Matthias
# ...                                            ...             ...
# 14182  https://www.airbnb.com/users/show/420514457               H
# 14183  https://www.airbnb.com/users/show/595670462         Philipp
# 14184  https://www.airbnb.com/users/show/595670462         Philipp
# 14185  https://www.airbnb.com/users/show/569536089         Tatjana
# 14186    https://www.airbnb.com/users/show/1099703          Moritz
#
#        host_since           host_location  ... availability_90  \
# 0      2008-10-19     Coledale, Australia  ...               4
# 1      2009-08-25         Berlin, Germany  ...               5
# 2      2009-11-18         Berlin, Germany  ...               0
# 3      2009-12-20          Santa Cruz, CA  ...               0
# 4      2010-01-08  Rio de Janeiro, Brazil  ...              17
# ...           ...                     ...  ...             ...
# 14182  2021-08-28         Berlin, Germany  ...              90
# 14183  2024-08-12         Berlin, Germany  ...              80
# 14184  2024-08-12         Berlin, Germany  ...              89
# 14185  2024-03-29         Berlin, Germany  ...              79
# 14186  2011-09-02         Berlin, Germany  ...              90
#
#       availability_365 number_of_reviews estimated_occupancy_l365d  \
# 0                  250               149                       126
# 1                  193                 7                         0
# 2                  262                26                         0
# 3                    0                48                         0
# 4                  111               298                         0
# ...                ...               ...                       ...
# 14182              365                 0                         0
# 14183              355                 0                         0
# 14184              364                 0                         0
# 14185              354                 0                         0
# 14186              365                 0                         0
#
#       estimated_revenue_l365d  review_scores_rating  \
# 0                     13230.0                  4.63
# 1                         0.0                  5.00
# 2                         0.0                  4.68
# 3                         NaN                  4.72
# 4                         0.0                  4.77
# ...                       ...                   ...
# 14182                     0.0                   NaN
# 14183                     0.0                   NaN
# 14184                     0.0                   NaN
# 14185                     0.0                   NaN
# 14186                     0.0                   NaN
#
#        review_scores_cleanliness review_scores_location review_scores_value  \
# 0                           4.52                   4.92                4.61
# 1                           5.00                   4.86                4.86
# 2                           4.85                   4.60                4.45
# 3                           4.86                   4.67                4.71
# 4                           4.71                   4.88                4.65
# ...                          ...                    ...                 ...
# 14182                        NaN                    NaN                 NaN
# 14183                        NaN                    NaN                 NaN
# 14184                        NaN                    NaN                 NaN
# 14185                        NaN                    NaN                 NaN
# 14186                        NaN                    NaN                 NaN
#
#       reviews_per_month
# 0                  0.76
# 1                  0.06
# 2                  0.14
# 3                  0.26
# 4                  1.60
# ...                 ...
# 14182               NaN
# 14183               NaN
# 14184               NaN
# 14185               NaN
# 14186               NaN
#
# [14187 rows x 50 columns]

# %%
# Observar valores nulos por columna
valores_nulos = df.isnull().sum()
valores_nulos_mayor_0 = valores_nulos[valores_nulos > 0]
valores_nulos_mayor_0
# Out:
# host_name                      13
# host_since                     13
# host_location                2970
# host_response_time           4974
# host_response_rate           4974
# host_acceptance_rate         4358
# host_is_superhost             211
# host_neighbourhood           8280
# host_listings_count            13
# host_total_listings_count      13
# host_verifications             13
# host_has_profile_pic           13
# host_identity_verified         13
# neighbourhood                7647
# bathrooms                    4955
# bathrooms_text                  7
# bedrooms                     2023
# beds                         5003
# price                        5004
# estimated_revenue_l365d      5004
# review_scores_rating         3349
# review_scores_cleanliness    3349
# review_scores_location       3352
# review_scores_value          3354
# reviews_per_month            3349
# dtype: int64

# %%
# Primera y segunda sustitución valores nulos para host_name y host_since
df_host = df[df['host_name'].isna()].head(20)

null_host_ids = df_host['host_id'].unique()
print(null_host_ids)

# Verificar que los host_id con valores nulos en host_name y host_since tengan datos en otras columnas
check_null = df[(df['host_id'].isin(null_host_ids)) & (df['host_name'].notna()) & (df['host_since'].notna())]
print(check_null)

# Sustitución por el str Unknown para howst_name y host_since debido a la falta de relación con otros host_id
df_clean = df.copy()
df_clean['host_name'] = df_clean['host_name'].fillna('Unknown')
df_clean['host_since'] = df_clean['host_since'].fillna('Unknown')

# Corroborar el cambio
print(df_clean.isnull().sum())
# Out:
# [  8154292  17070776   1083235  35130445  39488064  39830360   1086128
#   45740535  54224455    603195 104537266 331345013 108418649]
# Empty DataFrame
# Columns: [id, listing_url, last_scraped, source, name, host_id, host_url, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, availability_30, availability_60, availability_90, availability_365, number_of_reviews, estimated_occupancy_l365d, estimated_revenue_l365d, review_scores_rating, review_scores_cleanliness, review_scores_location, review_scores_value, reviews_per_month]
# Index: []
#
# [0 rows x 50 columns]
# id                                 0
# listing_url                        0
# last_scraped                       0
# source                             0
# name                               0
# host_id                            0
# host_url                           0
# host_name                          0
# host_since                         0
# host_location                   2970
# host_response_time              4974
# host_response_rate              4974
# host_acceptance_rate            4358
# host_is_superhost                211
# host_neighbourhood              8280
# host_listings_count               13
# host_total_listings_count         13
# host_verifications                13
# host_has_profile_pic              13
# host_identity_verified            13
# neighbourhood                   7647
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms                       4955
# bathrooms_text                     7
# bedrooms                        2023
# beds                            5003
# amenities                          0
# price                           5004
# minimum_nights                     0
# maximum_nights                     0
# minimum_nights_avg_ntm             0
# maximum_nights_avg_ntm             0
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# number_of_reviews                  0
# estimated_occupancy_l365d          0
# estimated_revenue_l365d         5004
# review_scores_rating            3349
# review_scores_cleanliness       3349
# review_scores_location          3352
# review_scores_value             3354
# reviews_per_month               3349
# dtype: int64

# %%
# Sustitución para host_location y neighborhood
''' Se utilizará neighbourhood_cleansed para sustituir los valores nulos en host_location y neighborhood.'''
df_clean['host_location'] = df.apply(lambda row: row['neighbourhood_cleansed'].lower() if pd.isna(row['host_location']) else row['host_location'], axis=1)

df_clean['neighbourhood'] = df.apply(lambda row:row['neighbourhood_cleansed'].lower() if pd.isna(row['neighbourhood']) else row['neighbourhood'], axis = 1)
# Corroborar la sustitución
df_clean.isnull().sum()
# Out:
# id                                 0
# listing_url                        0
# last_scraped                       0
# source                             0
# name                               0
# host_id                            0
# host_url                           0
# host_name                          0
# host_since                         0
# host_location                      0
# host_response_time              4974
# host_response_rate              4974
# host_acceptance_rate            4358
# host_is_superhost                211
# host_neighbourhood              8280
# host_listings_count               13
# host_total_listings_count         13
# host_verifications                13
# host_has_profile_pic              13
# host_identity_verified            13
# neighbourhood                      0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms                       4955
# bathrooms_text                     7
# bedrooms                        2023
# beds                            5003
# amenities                          0
# price                           5004
# minimum_nights                     0
# maximum_nights                     0
# minimum_nights_avg_ntm             0
# maximum_nights_avg_ntm             0
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# number_of_reviews                  0
# estimated_occupancy_l365d          0
# estimated_revenue_l365d         5004
# review_scores_rating            3349
# review_scores_cleanliness       3349
# review_scores_location          3352
# review_scores_value             3354
# reviews_per_month               3349
# dtype: int64

# %%
# Sustitución para host_response_time y host_response_rate

# Formato de host_response_rate y host_acceptance_rate a numérico
for col in ['host_response_rate', 'host_acceptance_rate']:
    df_clean[col] = pd.to_numeric(
        df_clean[col].astype(str).str.replace('%', '', regex=True),
        errors='coerce'
    )

""" Primero se sustituirán los valores nulos que estén en la misma fila de host_response_time por host_acceptance_rate. Luego."""
df_clean['host_response_rate'] = df_clean['host_response_rate'].fillna(df_clean['host_acceptance_rate'])
df_clean['host_response_time'] = df_clean['host_response_time'].fillna('No response')

# Sustitución para host_response_rate y host_acceptance_rate por un identificador numérico
df_clean['host_response_rate'].isin([88.88]).sum()
df_clean['host_acceptance_rate'].isin([89.89]).sum()

df_clean['host_response_rate'] = df_clean['host_response_rate'].fillna(88.88)
df_clean['host_acceptance_rate'] = df_clean['host_acceptance_rate'].fillna(89.89)

# Corroborar la sustitución
df_clean.isnull().sum()
# Out:
# id                                 0
# listing_url                        0
# last_scraped                       0
# source                             0
# name                               0
# host_id                            0
# host_url                           0
# host_name                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                211
# host_neighbourhood              8280
# host_listings_count               13
# host_total_listings_count         13
# host_verifications                13
# host_has_profile_pic              13
# host_identity_verified            13
# neighbourhood                      0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms                       4955
# bathrooms_text                     7
# bedrooms                        2023
# beds                            5003
# amenities                          0
# price                           5004
# minimum_nights                     0
# maximum_nights                     0
# minimum_nights_avg_ntm             0
# maximum_nights_avg_ntm             0
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# number_of_reviews                  0
# estimated_occupancy_l365d          0
# estimated_revenue_l365d         5004
# review_scores_rating            3349
# review_scores_cleanliness       3349
# review_scores_location          3352
# review_scores_value             3354
# reviews_per_month               3349
# dtype: int64

# %%
# Sustitución para los 211 na's de host_is_superhost utilizando el método backward fill
df_clean['host_is_superhost'] = df_clean['host_is_superhost'].fillna(method = 'bfill')
df_clean.isnull().sum()
# Out:
# /var/folders/c5/_p39j2b97hb2d064t5tdpypm0000gn/T/ipykernel_14639/4249748035.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_clean['host_is_superhost'] = df_clean['host_is_superhost'].fillna(method = 'bfill')
# id                                 0
# listing_url                        0
# last_scraped                       0
# source                             0
# name                               0
# host_id                            0
# host_url                           0
# host_name                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_neighbourhood              8280
# host_listings_count               13
# host_total_listings_count         13
# host_verifications                13
# host_has_profile_pic              13
# host_identity_verified            13
# neighbourhood                      0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms                       4955
# bathrooms_text                     7
# bedrooms                        2023
# beds                            5003
# amenities                          0
# price                           5004
# minimum_nights                     0
# maximum_nights                     0
# minimum_nights_avg_ntm             0
# maximum_nights_avg_ntm             0
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# number_of_reviews                  0
# estimated_occupancy_l365d          0
# estimated_revenue_l365d         5004
# review_scores_rating            3349
# review_scores_cleanliness       3349
# review_scores_location          3352
# review_scores_value             3354
# reviews_per_month               3349
# dtype: int64

# %%
# Sustitución para host_neighbourhood y sus 8280 na's
'Se utilizará host_neighbourhood_cleansed para sustituir los valores nulos en host_neighbourhood.'
df_clean['host_neighbourhood'] = df_clean['host_neighbourhood'].fillna(df_clean['neighbourhood_cleansed'])

# Formato a host_neighbourhood y neighbourhood_cleansed
df_clean['host_neighbourhood'] = df_clean['host_neighbourhood'].str.lower().str.strip()
df_clean['neighbourhood_cleansed'] = df_clean['neighbourhood_cleansed'].str.lower().str.strip()

# Corroborar la sustitución
df_clean.isnull().sum()
# Out:
# id                                 0
# listing_url                        0
# last_scraped                       0
# source                             0
# name                               0
# host_id                            0
# host_url                           0
# host_name                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_neighbourhood                 0
# host_listings_count               13
# host_total_listings_count         13
# host_verifications                13
# host_has_profile_pic              13
# host_identity_verified            13
# neighbourhood                      0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms                       4955
# bathrooms_text                     7
# bedrooms                        2023
# beds                            5003
# amenities                          0
# price                           5004
# minimum_nights                     0
# maximum_nights                     0
# minimum_nights_avg_ntm             0
# maximum_nights_avg_ntm             0
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# number_of_reviews                  0
# estimated_occupancy_l365d          0
# estimated_revenue_l365d         5004
# review_scores_rating            3349
# review_scores_cleanliness       3349
# review_scores_location          3352
# review_scores_value             3354
# reviews_per_month               3349
# dtype: int64

# %%
# Sustitución para los 13 na's host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified

# Debido a que no tienen otras propiedas registradas
df_clean['host_listings_count'] = df_clean['host_listings_count'].fillna(0)
df_clean['host_total_listings_count'] = df_clean['host_total_listings_count'].fillna(0)

# No se tiene información para sustituir
df_clean['host_verifications'] = df_clean['host_verifications'].fillna(method = 'bfill')

# Se asume que no tiene foto de perfil ni identidad verificada por falta de verificación
df_clean['host_has_profile_pic'] = df_clean['host_has_profile_pic'].fillna('f')
df_clean['host_identity_verified'] = df_clean['host_identity_verified'].fillna('f')

# Corroborar la sustitución
df_clean.isnull().sum()
# Out:
# /var/folders/c5/_p39j2b97hb2d064t5tdpypm0000gn/T/ipykernel_14639/1837327274.py:8: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_clean['host_verifications'] = df_clean['host_verifications'].fillna(method = 'bfill')
# id                                 0
# listing_url                        0
# last_scraped                       0
# source                             0
# name                               0
# host_id                            0
# host_url                           0
# host_name                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_neighbourhood                 0
# host_listings_count                0
# host_total_listings_count          0
# host_verifications                 0
# host_has_profile_pic               0
# host_identity_verified             0
# neighbourhood                      0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms                       4955
# bathrooms_text                     7
# bedrooms                        2023
# beds                            5003
# amenities                          0
# price                           5004
# minimum_nights                     0
# maximum_nights                     0
# minimum_nights_avg_ntm             0
# maximum_nights_avg_ntm             0
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# number_of_reviews                  0
# estimated_occupancy_l365d          0
# estimated_revenue_l365d         5004
# review_scores_rating            3349
# review_scores_cleanliness       3349
# review_scores_location          3352
# review_scores_value             3354
# reviews_per_month               3349
# dtype: int64

# %%
# Sustitución para los 4955 na's de bathrooms_text
'''Se observó una relación entre bathrooms_text y bathrooms. Se utilizará el número que de bathrooms que hay en bathrooms_text para sustituir los valores nulos en bathrooms.'''
df_clean['bathrooms'] = df_clean['bathrooms'].fillna(df_clean['bathrooms_text'].str.extract(r'(\d+(\.\d+)?)')[0].astype(float))

# Corroborar la sustitución, aun restan 31 na's para bathroom y 7 na's para bathrooms_text
df_clean['bathrooms'] = df_clean['bathrooms'].fillna(0)
df_clean['bathrooms_text'] = df_clean['bathrooms_text'].fillna(method = "ffill")

df_clean.isnull().sum()
# Out:
# /var/folders/c5/_p39j2b97hb2d064t5tdpypm0000gn/T/ipykernel_14639/4294771094.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_clean['bathrooms_text'] = df_clean['bathrooms_text'].fillna(method = "ffill")
# id                                 0
# listing_url                        0
# last_scraped                       0
# source                             0
# name                               0
# host_id                            0
# host_url                           0
# host_name                          0
# host_since                         0
# host_location                      0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_neighbourhood                 0
# host_listings_count                0
# host_total_listings_count          0
# host_verifications                 0
# host_has_profile_pic               0
# host_identity_verified             0
# neighbourhood                      0
# neighbourhood_cleansed             0
# neighbourhood_group_cleansed       0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms                          0
# bathrooms_text                     0
# bedrooms                        2023
# beds                            5003
# amenities                          0
# price                           5004
# minimum_nights                     0
# maximum_nights                     0
# minimum_nights_avg_ntm             0
# maximum_nights_avg_ntm             0
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# number_of_reviews                  0
# estimated_occupancy_l365d          0
# estimated_revenue_l365d         5004
# review_scores_rating            3349
# review_scores_cleanliness       3349
# review_scores_location          3352
# review_scores_value             3354
# reviews_per_month               3349
# dtype: int64

# %%
# Sustitución para bedrooms y beds, apoyado con IA, por la importancia y representatividad de las variables.
''' Se utilizará la mediana de bedrooms y beds en base a la columna accommodates, con la que puede tener correlación.'''
# Correlación
print(df_clean[['accommodates','bedrooms','beds']].corr(method='pearson'))

#bedrooms
df_clean['bedrooms'] = df_clean['bedrooms'].fillna(
    df_clean.groupby('accommodates')['bedrooms'].transform('median')
).fillna(df_clean['bedrooms'].median())

#beds
df_clean['beds'] = df_clean['beds'].fillna(
    df_clean.groupby('accommodates')['beds'].transform('median')
).fillna(df_clean['bedrooms']).fillna(df_clean['beds'].median())

# Corroborar la sustitución
df_clean.isnull().sum()
# Out:
#               accommodates  bedrooms      beds
# accommodates      1.000000  0.686321  0.790940
# bedrooms          0.686321  1.000000  0.603651
# beds              0.790940  0.603651  1.000000
# id                              0
# listing_url                     0
# last_scraped                    0
# source                          0
# name                            0
# host_id                         0
# host_url                        0
# host_name                       0
# host_since                      0
# host_location                   0
# host_response_time              0
# host_response_rate              0
# host_acceptance_rate            0
# host_is_superhost               0
# host_neighbourhood              0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# host_has_profile_pic            0
# host_identity_verified          0
# neighbourhood                   0
# neighbourhood_cleansed          0
# neighbourhood_group_cleansed    0
# latitude                        0
# longitude                       0
# property_type                   0
# room_type                       0
# accommodates                    0
# bathrooms                       0
# bathrooms_text                  0
# bedrooms                        0
# beds                            0
# amenities                       0
# price                           0
# minimum_nights                  0
# maximum_nights                  0
# minimum_nights_avg_ntm          0
# maximum_nights_avg_ntm          0
# availability_30                 0
# availability_60                 0
# availability_90                 0
# availability_365                0
# number_of_reviews               0
# estimated_occupancy_l365d       0
# estimated_revenue_l365d         0
# review_scores_rating            0
# review_scores_cleanliness       0
# review_scores_location          0
# review_scores_value             0
# reviews_per_month               0
# dtype: int64

# %%
# Sustitución para los 5004 valores de Price.
## Formato de price, asegurando trabajar con string para luego reemplazar $ y ,
df_clean['price'] = df_clean['price'].astype(str).str.replace('[$,]', '', regex = True).astype(float)

# Media por roomtype
df_clean['room_type'].value_counts()
mean_prices = df_clean.groupby('room_type')['price'].mean()
print(mean_prices)

# Sustitución con la media por tipo de habitación
df_clean['price'] = df_clean.apply(lambda row:mean_prices[row['room_type']] if pd.isna(row['price']) else row['price'], axis = 1)

# Corroborar
df_clean.isnull().sum()
# Out:
# room_type
# Entire home/apt     173.672536
# Hotel room         5769.547368
# Private room         96.791219
# Shared room          66.091837
# Name: price, dtype: float64
# id                              0
# listing_url                     0
# last_scraped                    0
# source                          0
# name                            0
# host_id                         0
# host_url                        0
# host_name                       0
# host_since                      0
# host_location                   0
# host_response_time              0
# host_response_rate              0
# host_acceptance_rate            0
# host_is_superhost               0
# host_neighbourhood              0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# host_has_profile_pic            0
# host_identity_verified          0
# neighbourhood                   0
# neighbourhood_cleansed          0
# neighbourhood_group_cleansed    0
# latitude                        0
# longitude                       0
# property_type                   0
# room_type                       0
# accommodates                    0
# bathrooms                       0
# bathrooms_text                  0
# bedrooms                        0
# beds                            0
# amenities                       0
# price                           0
# minimum_nights                  0
# maximum_nights                  0
# minimum_nights_avg_ntm          0
# maximum_nights_avg_ntm          0
# availability_30                 0
# availability_60                 0
# availability_90                 0
# availability_365                0
# number_of_reviews               0
# estimated_occupancy_l365d       0
# estimated_revenue_l365d         0
# review_scores_rating            0
# review_scores_cleanliness       0
# review_scores_location          0
# review_scores_value             0
# reviews_per_month               0
# dtype: int64

# %%
# Sustitución para estimated_revenue_l365d y sus 5004 na's.
''' 
Se identificó que si estimated_occupancy_l365d es 0, por consecuencia estimated_revenue_l365d será 0, así que se empezará por esa sustitución, además si hay estimated_occupancy, será multiplicado por el precio
'''
df_clean.loc[df_clean['estimated_occupancy_l365d'] == 0, 'estimated_revenue_l365d'] = 0

df_clean['estimated_revenue_l365d'] = df_clean['estimated_revenue_l365d'].fillna(df_clean['price'] * df_clean['estimated_occupancy_l365d'])

df_clean.isnull().sum()
# Out:
# id                              0
# listing_url                     0
# last_scraped                    0
# source                          0
# name                            0
# host_id                         0
# host_url                        0
# host_name                       0
# host_since                      0
# host_location                   0
# host_response_time              0
# host_response_rate              0
# host_acceptance_rate            0
# host_is_superhost               0
# host_neighbourhood              0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# host_has_profile_pic            0
# host_identity_verified          0
# neighbourhood                   0
# neighbourhood_cleansed          0
# neighbourhood_group_cleansed    0
# latitude                        0
# longitude                       0
# property_type                   0
# room_type                       0
# accommodates                    0
# bathrooms                       0
# bathrooms_text                  0
# bedrooms                        0
# beds                            0
# amenities                       0
# price                           0
# minimum_nights                  0
# maximum_nights                  0
# minimum_nights_avg_ntm          0
# maximum_nights_avg_ntm          0
# availability_30                 0
# availability_60                 0
# availability_90                 0
# availability_365                0
# number_of_reviews               0
# estimated_occupancy_l365d       0
# estimated_revenue_l365d         0
# review_scores_rating            0
# review_scores_cleanliness       0
# review_scores_location          0
# review_scores_value             0
# reviews_per_month               0
# dtype: int64

# %%
# Sustitución para los Na's de review_scores_rating, review_scores_cleanliness, review_scores_location, review_scores_value and reviews_per_month
''' 
Se identificó que si no se tiene estimated_occupancy_l365d, en algunos casos no se tiene review scores rating/cleanliness/location/value/month, entonces se empezará con esa primera sustitución.
'''
reviews_col = ['review_scores_rating', 'review_scores_cleanliness', 'review_scores_location', 'review_scores_value', 'reviews_per_month']
df_clean.loc[df_clean['number_of_reviews'] == 0, reviews_col] = 0

# Los na's restantes se llenaran utilizando el método forward fill. Solo quedaron 3 na's en review_scores_location y 5 na's en review_scores_value
df_clean['review_scores_value'] = df_clean['review_scores_value'].fillna(method = 'ffill')
df_clean['review_scores_location'] = df_clean['review_scores_location'].fillna(method = 'ffill')

# Última corraboración
df_clean.isnull().sum()
# Out:
# /var/folders/c5/_p39j2b97hb2d064t5tdpypm0000gn/T/ipykernel_14639/3580919761.py:9: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_clean['review_scores_value'] = df_clean['review_scores_value'].fillna(method = 'ffill')
# /var/folders/c5/_p39j2b97hb2d064t5tdpypm0000gn/T/ipykernel_14639/3580919761.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_clean['review_scores_location'] = df_clean['review_scores_location'].fillna(method = 'ffill')
# id                              0
# listing_url                     0
# last_scraped                    0
# source                          0
# name                            0
# host_id                         0
# host_url                        0
# host_name                       0
# host_since                      0
# host_location                   0
# host_response_time              0
# host_response_rate              0
# host_acceptance_rate            0
# host_is_superhost               0
# host_neighbourhood              0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# host_has_profile_pic            0
# host_identity_verified          0
# neighbourhood                   0
# neighbourhood_cleansed          0
# neighbourhood_group_cleansed    0
# latitude                        0
# longitude                       0
# property_type                   0
# room_type                       0
# accommodates                    0
# bathrooms                       0
# bathrooms_text                  0
# bedrooms                        0
# beds                            0
# amenities                       0
# price                           0
# minimum_nights                  0
# maximum_nights                  0
# minimum_nights_avg_ntm          0
# maximum_nights_avg_ntm          0
# availability_30                 0
# availability_60                 0
# availability_90                 0
# availability_365                0
# number_of_reviews               0
# estimated_occupancy_l365d       0
# estimated_revenue_l365d         0
# review_scores_rating            0
# review_scores_cleanliness       0
# review_scores_location          0
# review_scores_value             0
# reviews_per_month               0
# dtype: int64

# %%
# Guardar df_clean a csv
df_clean.to_csv('Berlin_Clean.csv', index = False)

# %%
# Corroborar
df_berlin = pd.read_csv('Berlin_Clean.csv')
df_berlin.isnull().sum()
# Out:
# id                              0
# listing_url                     0
# last_scraped                    0
# source                          0
# name                            0
# host_id                         0
# host_url                        0
# host_name                       0
# host_since                      0
# host_location                   0
# host_response_time              0
# host_response_rate              0
# host_acceptance_rate            0
# host_is_superhost               0
# host_neighbourhood              0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# host_has_profile_pic            0
# host_identity_verified          0
# neighbourhood                   0
# neighbourhood_cleansed          0
# neighbourhood_group_cleansed    0
# latitude                        0
# longitude                       0
# property_type                   0
# room_type                       0
# accommodates                    0
# bathrooms                       0
# bathrooms_text                  0
# bedrooms                        0
# beds                            0
# amenities                       0
# price                           0
# minimum_nights                  0
# maximum_nights                  0
# minimum_nights_avg_ntm          0
# maximum_nights_avg_ntm          0
# availability_30                 0
# availability_60                 0
# availability_90                 0
# availability_365                0
# number_of_reviews               0
# estimated_occupancy_l365d       0
# estimated_revenue_l365d         0
# review_scores_rating            0
# review_scores_cleanliness       0
# review_scores_location          0
# review_scores_value             0
# reviews_per_month               0
# dtype: int64
